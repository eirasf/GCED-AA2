# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/eirasf/GCED-AA2/blob/main/es/lab1/1_PrimerCuaderno.ipynb)

# %%
print("Hola mundo")
# Out:
# Hola mundo

# %% [markdown]
# Hola, este es mi primer notebook
