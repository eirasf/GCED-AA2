# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/eirasf/GCED-AA2/blob/main/en/lab1/2_Order_importance.ipynb)

# %%
import numpy as np
def square(x):
  return x*x

# %%
x=np.random.randint(1,11)
y=square(x)

# %%
print("Squaring", x, "yields", y )

# %% [markdown]
# Be careful when re-running cells, because the results may become incorrect

# %%
y=3
